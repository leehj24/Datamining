# %% [markdown]
# # 1.TensorFlow 및 Keras

# %%
import keras
keras.__version__
# Out:
# '2.8.0'

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
np.__version__
# Out:
# '1.21.6'

# %%
tf.__version__
# Out:
# '2.8.2'

# %%
keras.__version__
# Out:
# '2.8.0'

# %% [markdown]
# # 2.파일 업로드

# %% [markdown]
# ## 2.1 일반 업로드

# %% [markdown]
# * 이미지 파일을 업로드하고, python에서 불러오기

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-08ada621-f007-414b-bd2d-0e54fe161c16" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-08ada621-f007-414b-bd2d-0e54fe161c16">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lenna.png to lenna.png

# %%
import cv2

img = cv2.imread("lenna.png")
img.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# ## 2.2 구글 드라이브 연동

# %% [markdown]
# 1. 코드에서 직접 구글 드라이브 마운트
# 2. 왼쪽의 폴더 아이콘에서 구글 드라이브 아이콘으로 마운트

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
import cv2
import numpy as np

img = cv2.imread("/gdrive/My Drive/lecture_220711/resources/lenna.png")
img.shape
# Out:
# (512, 512, 3)
