# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary.reversed())
    plt.xlabel(y_train[i])
plt.show()

# %% [markdown]
# 함수형

# %%
def mnist_model(image_size=(28, 28)):
    input = tf.keras.layers.Input(image_size)
    flatten = tf.keras.layers.Flatten()(input)
    dense_1 = tf.keras.layers.Dense(128, activation=tf.keras.activations.relu)(flatten)
    dense_2 = tf.keras.layers.Dense(10, activation=tf.keras.activations.softmax)(dense_1)

    return tf.keras.models.Model(inputs=[input], outputs=[dense_2])

# %%
model_2_before_training = mnist_model()
model_2_before_training.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28)]          0
#
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 128)               100480
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_2 = mnist_model()
model_2.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
history_2 = model_2.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2605 - accuracy: 0.9259
# Epoch 2/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1124 - accuracy: 0.9673
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0779 - accuracy: 0.9768
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0596 - accuracy: 0.9817
# Epoch 5/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0461 - accuracy: 0.9858
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0367 - accuracy: 0.9885
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0290 - accuracy: 0.9908
# Epoch 8/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0244 - accuracy: 0.9924
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0198 - accuracy: 0.9937
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0162 - accuracy: 0.9951

# %% [markdown]
# 추가

# %%
def mnist_model_with_dropout(image_size=(28, 28)):
    input = tf.keras.layers.Input(image_size)
    flatten = tf.keras.layers.Flatten()(input)
    dense_1 = tf.keras.layers.Dense(128, activation=tf.keras.activations.relu)(flatten)
    dropout_1 = tf.keras.layers.Dropout(0.2)(dense_1)
    dense_2 = tf.keras.layers.Dense(10, activation=tf.keras.activations.softmax)(dropout_1)

    return tf.keras.models.Model(inputs=[input], outputs=[dense_2])

# %%
model_3 = mnist_model()
model_3.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
history_3 = model_3.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2631 - accuracy: 0.9247
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1160 - accuracy: 0.9653
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0800 - accuracy: 0.9761
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0586 - accuracy: 0.9820
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0458 - accuracy: 0.9858
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0351 - accuracy: 0.9890
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0290 - accuracy: 0.9912
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0241 - accuracy: 0.9923
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0182 - accuracy: 0.9946
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0165 - accuracy: 0.9950

# %%
model_3.evaluate(x_test, y_test, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.0792 - accuracy: 0.9796 - 520ms/epoch - 2ms/step
# [0.07922417670488358, 0.9796000123023987]

# %% [markdown]
# 예측

# %%
import numpy as np
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary.reversed())

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

  def plot_predicted(predictions):
    num_rows = 5
    num_cols = 3
    num_images = num_rows*num_cols
    plt.figure(figsize=(2*2*num_cols, 2*num_rows))
    for i in range(num_images):
        plt.subplot(num_rows, 2*num_cols, 2*i+1)
        plot_image(i, predictions[i], y_test, x_test)
        plt.subplot(num_rows, 2*num_cols, 2*i+2)
        plot_value_array(i, predictions[i], y_test)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# 모델

# %%
predictions = model.predict(x_test)

# %%
plot_predicted(predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-2cd0fbb80b38> in <module>()
# ----> 1 plot_predicted(predictions)
#
# NameError: name 'plot_predicted' is not defined
